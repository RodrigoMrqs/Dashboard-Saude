# %%
import pandas as pd
df = pd.read_csv("Dataset de Notificações de Síndrome Gripal - part-00000-d0823714-0f9e-4bbe-83d8-c50e1c8324c4.c000.csv.csv", encoding="utf-8")
print(df.columns.tolist())
# Out:
# C:\Users\SAMSUNG\AppData\Local\Temp\ipykernel_18268\3755766177.py:2: DtypeWarning: Columns (62) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Dataset de Notificações de Síndrome Gripal - part-00000-d0823714-0f9e-4bbe-83d8-c50e1c8324c4.c000.csv.csv", encoding="utf-8")
# ...
